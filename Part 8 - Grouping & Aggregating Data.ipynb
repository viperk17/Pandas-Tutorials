# %%
import pandas as pd

df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head(2)
# Out:
#                                 MainBranch Hobbyist  Age Age1stCode CompFreq  \
# Respondent
# 1           I am a developer by profession      Yes  NaN         13  Monthly
# 2           I am a developer by profession       No  NaN         19      NaN
#
#             CompTotal  ConvertedComp         Country    CurrencyDesc  \
# Respondent
# 1                 NaN            NaN         Germany   European Euro
# 2                 NaN            NaN  United Kingdom  Pound sterling
#
#            CurrencySymbol DatabaseDesireNextYear  \
# Respondent
# 1                     EUR   Microsoft SQL Server
# 2                     GBP                    NaN
#
#                                    DatabaseWorkedWith  \
# Respondent
# 1           Elasticsearch;Microsoft SQL Server;Oracle
# 2                                                 NaN
#
#                                                       DevType  \
# Respondent
# 1           Developer, desktop or enterprise applications;...
# ...

# %%
df['ConvertedComp'].head(15)
# Out:
# Respondent
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8     116000.0
# 9          NaN
# 10     32315.0
# 11     40070.0
# 12     14268.0
# 13     38916.0
# 14     66000.0
# 15         NaN
# Name: ConvertedComp, dtype: float64

# %%
df['ConvertedComp'].nlargest(15)
# Out:
# Respondent
# 123     2000000.0
# 125     2000000.0
# 193     2000000.0
# 665     2000000.0
# 699     2000000.0
# 724     2000000.0
# 818     2000000.0
# 986     2000000.0
# 1022    2000000.0
# 1036    2000000.0
# 1117    2000000.0
# 1128    2000000.0
# 1193    2000000.0
# 1296    2000000.0
# 1345    2000000.0
# Name: ConvertedComp, dtype: float64

# %%
df['ConvertedComp'].median()
# Out:
# 54049.0

# %%
df.median()
# Out:
# Age                 29.0
# CompTotal        63000.0
# ConvertedComp    54049.0
# WorkWeekHrs         40.0
# dtype: float64

# %%
df.describe()
# Out:
#                 Age      CompTotal  ConvertedComp   WorkWeekHrs
# count  45446.000000   3.482600e+04   3.475600e+04  41151.000000
# mean      30.834111  3.190464e+242   1.037561e+05     40.782174
# std        9.585392            inf   2.268853e+05     17.816383
# min        1.000000   0.000000e+00   0.000000e+00      1.000000
# 25%       24.000000   2.000000e+04   2.464800e+04     40.000000
# 50%       29.000000   6.300000e+04   5.404900e+04     40.000000
# 75%       35.000000   1.250000e+05   9.500000e+04     44.000000
# max      279.000000  1.111111e+247   2.000000e+06    475.000000

# %%
df['ConvertedComp'].count()
# Out:
# 34756

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4        Yes
# 5        Yes
#         ...
# 64858    Yes
# 64867    Yes
# 64898    Yes
# 64925    Yes
# 65112    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
# df['SocialMedia']
schema_df.sort_index()
# Out:
#                                                                    QuestionText
# Column
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# DatabaseDesireNextYear        Which database environments have you done exte...
# DatabaseWorkedWith            Which database environments have you done exte...
# DevType                       Which of the following describe you? Please se...
# ...

# %%
df['Sexuality'].value_counts(normalize=True)
# Out:
# Straight / Heterosexual                                  0.911939
# Bisexual                                                 0.043599
# Gay or Lesbian                                           0.022231
# Bisexual;Straight / Heterosexual                         0.005865
# Queer                                                    0.005660
# Bisexual;Queer                                           0.004342
# Gay or Lesbian;Queer                                     0.002046
# Straight / Heterosexual;Queer                            0.001273
# Bisexual;Gay or Lesbian                                  0.000909
# Bisexual;Gay or Lesbian;Straight / Heterosexual;Queer    0.000887
# Bisexual;Gay or Lesbian;Queer                            0.000546
# Gay or Lesbian;Straight / Heterosexual                   0.000296
# Bisexual;Straight / Heterosexual;Queer                   0.000227
# Bisexual;Gay or Lesbian;Straight / Heterosexual          0.000182
# Name: Sexuality, dtype: float64

# %%
df['Ethnicity'].value_counts(normalize=True)
# Out:
# White or of European descent                                                                                                            0.638069
# South Asian                                                                                                                             0.097219
# Hispanic or Latino/a/x                                                                                                                  0.049099
# Black or of African descent                                                                                                             0.036781
# Southeast Asian                                                                                                                         0.036694
#                                                                                                                                           ...
# ...

# %%
df['Country'].value_counts()
# Out:
# United States                         12469
# India                                  8403
# United Kingdom                         3896
# Germany                                3890
# Canada                                 2191
#                                       ...
# Kiribati                                  1
# Micronesia, Federated States of...        1
# Lesotho                                   1
# Chad                                      1
# Saint Lucia                               1
# Name: Country, Length: 183, dtype: int64

# %% [markdown]
# # Use Group By

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('India')
# Out:
#                                         MainBranch Hobbyist   Age Age1stCode  \
# Respondent
# 7                   I am a developer by profession      Yes   NaN         18
# 22                  I am a developer by profession      Yes   NaN         18
# 58                  I am a developer by profession      Yes   NaN         22
# 63          I am a student who is learning to code      Yes  21.0         17
# 149                 I am a developer by profession      Yes  36.0         31
# ...                                            ...      ...   ...        ...
# 54757                                          NaN      Yes   NaN         18
# 55407                                          NaN      Yes   NaN        NaN
# 62464                                          NaN      Yes   NaN        NaN
# 62954                                          NaN      Yes   NaN        NaN
# 64236                                          NaN      Yes   NaN        NaN
#
# ...

# %%
filt = df['Country'] == 'United States'
df.loc[filt]['Sexuality'].value_counts()
# Out:
# Straight / Heterosexual                                  8535
# Bisexual                                                  497
# Gay or Lesbian                                            294
# Queer                                                     114
# Bisexual;Queer                                             85
# Bisexual;Straight / Heterosexual                           59
# Gay or Lesbian;Queer                                       49
# Straight / Heterosexual;Queer                              19
# Bisexual;Gay or Lesbian;Queer                              12
# Bisexual;Gay or Lesbian                                     7
# Bisexual;Gay or Lesbian;Straight / Heterosexual             4
# Bisexual;Straight / Heterosexual;Queer                      4
# Bisexual;Gay or Lesbian;Straight / Heterosexual;Queer       4
# Gay or Lesbian;Straight / Heterosexual                      3
# Name: Sexuality, dtype: int64

# %%
country_grp['Sexuality'].value_counts().head(50)
# Out:
# Country              Sexuality
# Afghanistan          Straight / Heterosexual                                   11
#                      Bisexual                                                   5
#                      Bisexual;Gay or Lesbian;Straight / Heterosexual;Queer      1
#                      Gay or Lesbian                                             1
#                      Queer                                                      1
# Albania              Straight / Heterosexual                                   27
#                      Bisexual                                                   1
#                      Queer                                                      1
# Algeria              Straight / Heterosexual                                   38
#                      Bisexual                                                   2
# Andorra              Straight / Heterosexual                                    3
# ...

# %%
country_grp['Sexuality'].value_counts(normalize=True).loc['India']
# Out:
# Sexuality
# Straight / Heterosexual                                  0.947742
# Bisexual                                                 0.040704
# Bisexual;Straight / Heterosexual                         0.003151
# Gay or Lesbian                                           0.002626
# Queer                                                    0.002363
# Bisexual;Gay or Lesbian;Straight / Heterosexual;Queer    0.000788
# Bisexual;Queer                                           0.000788
# Gay or Lesbian;Straight / Heterosexual                   0.000788
# Bisexual;Gay or Lesbian;Straight / Heterosexual          0.000263
# Bisexual;Straight / Heterosexual;Queer                   0.000263
# Gay or Lesbian;Queer                                     0.000263
# Straight / Heterosexual;Queer                            0.000263
# Name: Sexuality, dtype: float64

# %%
country_grp['ConvertedComp'].median()
# Out:
# Country
# Afghanistan                             15163.5
# Albania                                 15900.0
# Algeria                                  9432.0
# Andorra                                 88640.0
# Angola                                   5292.0
#                                          ...
# Venezuela, Bolivarian Republic of...     3600.0
# Viet Nam                                10344.0
# Yemen                                   36000.0
# Zambia                                   5452.0
# Zimbabwe                                 7200.0
# Name: ConvertedComp, Length: 183, dtype: float64

# %%
# For specific country

country_grp['ConvertedComp'].median().loc['Germany']
# Out:
# 62697.0

# %%
country_grp['ConvertedComp'].agg(['median','mean']).loc['India']
# Out:
# median    10056.000000
# mean      28751.271364
# Name: India, dtype: float64

# %%
filt = df['Country'] == 'United States'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python')
# Out:
# Respondent
# 5        False
# 8         True
# 14       False
# 17        True
# 18       False
#          ...
# 58498     True
# 58896    False
# 60931    False
# 63077     True
# 64858      NaN
# Name: LanguageWorkedWith, Length: 12469, dtype: object

# %%
# Sum of python users

filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 2670

# %%
country_grp['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-cda55dd00399> in <module>
# ----> 1 country_grp['LanguageWorkedWith'].str.contains('Python').sum()
#
# ~/.local/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     750             return self[attr]
#     751
# --> 752         raise AttributeError(
#     753             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     754         )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
# use apply method 

country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              11
# Albania                                  13
# Algeria                                  40
# Andorra                                   3
# Angola                                    1
#                                        ...
# Venezuela, Bolivarian Republic of...     29
# Viet Nam                                102
# Yemen                                     1
# Zambia                                    4
# Zimbabwe                                 13
# Name: LanguageWorkedWith, Length: 183, dtype: int64

# %%
# Get %age of dev who know python
# grab total no of respondents from each country who have answered the survey

country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# United States                         12469
# India                                  8403
# United Kingdom                         3896
# Germany                                3890
# Canada                                 2191
#                                       ...
# Kiribati                                  1
# Micronesia, Federated States of...        1
# Lesotho                                   1
# Chad                                      1
# Saint Lucia                               1
# Name: Country, Length: 183, dtype: int64

# %%
country_uses_python = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                              11
# Albania                                  13
# Algeria                                  40
# Andorra                                   3
# Angola                                    1
#                                        ...
# Venezuela, Bolivarian Republic of...     29
# Viet Nam                                102
# Yemen                                     1
# Zambia                                    4
# Zimbabwe                                 13
# Name: LanguageWorkedWith, Length: 183, dtype: int64

# %%
# Combine two series in one
python_df = pd.concat([country_respondents, country_uses_python], axis='columns',sort=False)
python_df
# Out:
#                                     Country  LanguageWorkedWith
# United States                         12469                5964
# India                                  8403                2670
# United Kingdom                         3896                1621
# Germany                                3890                1712
# Canada                                 2191                1011
# ...                                     ...                 ...
# Kiribati                                  1                   0
# Micronesia, Federated States of...        1                   1
# Lesotho                                   1                   0
# Chad                                      1                   0
# Saint Lucia                               1                   1
#
# [183 rows x 2 columns]

# %%
python_df.rename(columns={'Country':'NumRespondents','LanguageWorkedWith':'NumKnowsPython'}, inplace=True)

# %%
python_df
# Out:
#                                     NumRespondents  NumKnowsPython
# United States                                12469            5964
# India                                         8403            2670
# United Kingdom                                3896            1621
# Germany                                       3890            1712
# Canada                                        2191            1011
# ...                                            ...             ...
# Kiribati                                         1               0
# Micronesia, Federated States of...               1               1
# Lesotho                                          1               0
# Chad                                             1               0
# Saint Lucia                                      1               1
#
# [183 rows x 2 columns]

# %%
# python_df['PctKnowsPython'] = (part/whole)

python_df['PctKnowsPython'] = (python_df['NumKnowsPython']/python_df['NumRespondents']) * 100
python_df
# Out:
#                                     NumRespondents  NumKnowsPython  \
# United States                                12469            5964
# India                                         8403            2670
# United Kingdom                                3896            1621
# Germany                                       3890            1712
# Canada                                        2191            1011
# ...                                            ...             ...
# Kiribati                                         1               0
# Micronesia, Federated States of...               1               1
# Lesotho                                          1               0
# Chad                                             1               0
# Saint Lucia                                      1               1
#
#                                     PctKnowsPython
# United States                            47.830620
# India                                    31.774366
# ...

# %%
python_df.sort_values(by='PctKnowsPython', ascending=False, inplace=True)

# %%
python_df.head(40)
# Out:
#                                     NumRespondents  NumKnowsPython  \
# Saint Lucia                                      1               1
# Micronesia, Federated States of...               1               1
# Gabon                                            1               1
# Montenegro                                      13               9
# Brunei Darussalam                                3               2
# Guyana                                           5               3
# Swaziland                                        7               4
# Iceland                                         53              28
# Finland                                        349             183
# Uganda                                          81              42
# Mauritania                                       4               2
# Burkina Faso                                     6               3
# Papua New Guinea                                 2               1
# ...

# %%
python_df.loc['Japan']
# Out:
# NumRespondents    297.000000
# NumKnowsPython    132.000000
# PctKnowsPython     44.444444
# Name: Japan, dtype: float64
